# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
matplotlib.rcParams['figure.figsize']=(12.0, 8.0)
import numpy as np
ara=np.fromfile("subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.raw",\
                dtype='int16').reshape((-1,512,512))
with open("subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.mhd","r") as f:
    print(f.read())
# Out:
# ObjectType = Image
# NDims = 3
# BinaryData = True
# BinaryDataByteOrderMSB = False
# CompressedData = False
# TransformMatrix = 1 0 0 0 1 0 0 0 1
# Offset = -198.10000600000001 -195 -335.209991
# CenterOfRotation = 0 0 0
# AnatomicalOrientation = RAI
# ElementSpacing = 0.7617189884185791 0.7617189884185791 2.5
# DimSize = 512 512 121
# ElementType = MET_SHORT
# ElementDataFile = 1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.raw

# %%
plt.hist(ara[30:110,150:350,0:250].flatten(), 30, normed=1)
plt.show()

# %%
a=ara[30:110,150:350,0:250]
for i in range(0,ara.shape[0],10):
    plt.imshow(np.clip(a[i,:,:],-950,-700),cmap=cm.Greys_r)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-7007a76830cf> in <module>()
#       1 a=ara[30:110,150:350,0:250]
#       2 for i in range(0,ara.shape[0],10):
# ----> 3     plt.imshow(np.clip(a[i,:,:],-950,-700),cmap=cm.Greys_r)
#       4     plt.show()
#
# IndexError: index 80 is out of bounds for axis 0 with size 80

# %%
f=open("subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.mhd","r")

# %%
print(f.read())
# Out:
# ObjectType = Image
# NDims = 3
# BinaryData = True
# BinaryDataByteOrderMSB = False
# CompressedData = False
# TransformMatrix = 1 0 0 0 1 0 0 0 1
# Offset = -198.10000600000001 -195 -335.209991
# CenterOfRotation = 0 0 0
# AnatomicalOrientation = RAI
# ElementSpacing = 0.7617189884185791 0.7617189884185791 2.5
# DimSize = 512 512 121
# ElementType = MET_SHORT
# ElementDataFile = 1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.raw
